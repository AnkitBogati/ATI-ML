# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from tensorflow import keras
from tensorflow.keras import layers

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Task 2: Loading and Preprocessing Image Data in keras:

# %%
train_dir = "/kaggle/input/fruitamamzon/FruitinAmazon/train"  # Change this to your actual dataset path
test_dir = "/kaggle/input/fruitamamzon/FruitinAmazon/test"
classes = os.listdir(train_dir)  # Get list of class directories

# %%
# Print the number of images in each class
for class_name in classes:
    class_path = os.path.join(train_dir, class_name)
    num_images = len(os.listdir(class_path))
    print(f"Class {class_name}: {num_images} images")
# Out:
# Class pupunha: 15 images
# Class graviola: 15 images
# Class tucuma: 15 images
# Class cupuacu: 15 images
# Class guarana: 15 images
# Class acai: 15 images

# %%
import random
# Visualize a random sample image from each of the first 6 classes
fig, axes = plt.subplots(2, 3, figsize=(12, 8))  # 2 rows, 3 columns

for i, class_name in enumerate(classes[:6]):  # Show 6 sample images
    class_path = os.path.join(train_dir, class_name)
    sample_image = random.choice(os.listdir(class_path))  # Pick a random image
    img = Image.open(os.path.join(class_path, sample_image))

    # Calculate row and column indices
    row = i // 3
    col = i % 3

    axes[row, col].imshow(img)
    axes[row, col].set_title(class_name)
    axes[row, col].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for Corrupted Image:

# %%
import os
import shutil
from PIL import Image



# Initialize a list to keep track of corrupted images
corrupted_images = []

# Iterate through each class subdirectory
for class_name in os.listdir(train_dir):
    class_path = os.path.join(train_dir, class_name)

    # Ensure it is a directory
    if os.path.isdir(class_path):
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)

            try:
                # Attempt to open the image
                with Image.open(image_path) as img:
                    img.verify()  # Verify that it is a valid image
            except (IOError, SyntaxError) as e:
                # If the image is corrupted, remove it
                os.remove(image_path)
                corrupted_images.append(image_path)
                print(f"Removed corrupted image: {image_path}")

# Print the final message
if not corrupted_images:
    print("No corrupted images found.")
# Out:
# No corrupted images found.

# %% [markdown]
# # Task 2: Loading and Preprocessing Image Data in keras:

# %%
# Define image size and batch size
img_height = 128 # Example image height
img_width = 128 # Example image width
batch_size = 32
validation_split = 0.2 # 80% training, 20% validation

# %%
# Create a preprocessing layer for normalization
rescale = tf.keras.layers.Rescaling(1./255) # Normalize pixel values to [0, 1]

# %%
# Create training dataset with normalization
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
train_dir,
labels="inferred",
label_mode="int",
image_size=(img_height, img_width),
interpolation="nearest",
batch_size=batch_size,
shuffle=True,
validation_split=validation_split,
subset="training",
seed=123
)
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.

# %%
# Apply the normalization (Rescaling) to the dataset
train_ds = train_ds.map(lambda x, y: (rescale(x), y))

# %%
# Create validation dataset with normalization
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
train_dir,
labels="inferred",
label_mode="int",
image_size=(img_height, img_width),
interpolation="nearest",
batch_size=batch_size,
shuffle=False,
validation_split=validation_split,
subset="validation",
seed=123
)
# Out:
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %%
# Apply the normalization (Rescaling) to the validation dataset
val_ds = val_ds.map(lambda x, y: (rescale(x), y))

# %%
# Create test dataset with normalization
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False  # Important to keep test data in original order
)

# Apply the normalization (Rescaling) to the test dataset
test_ds = test_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 30 files belonging to 6 classes.

# %% [markdown]
# # Task 3 - Implement a CNN with
# Follow the following Structure and Hyper - parameters:
#
# Convolutional Architecture:
#
# Convolutional Layer 1:
# Filter Size (F): (3, 3)
# Number of Filters (k): 32
# Padding (P): same
# Stride (s): 1
# Activation Layer: ReLU activation
# Pooling Layer 1: Max pooling
# Filter Size (F): (2, 2)
# Stride (s): 2
# Convolutional Layer 2:
# Filter Size (F): (3, 3)
# Number of Filters (k): 32
# Padding (P): same
# Stride (s): 1
# Activation Layer: ReLU activation
# Pooling Layer 2: Max pooling
# Filter Size (F): (2, 2)
# Stride (s): 2
# Fully Connected Network Architecture:
#
# Flatten Layer: Flatten the input coming from the convolutional layers
# Input Layer:
# Hidden Layer - 2:
# Number of Neurons: 64
# Number of Neurons: 128
# Output Layer:
# Number of Neurons: num classes (number of output classes)

# %%
# Define the number of output classes
num_classes = 6  # Adjust this based on your dataset


# Define the CNN model
model = keras.Sequential([
    # Convolutional Layer 1
    layers.Conv2D(32, (3, 3), activation="relu", input_shape=(128,128, 3), padding="same"),
    layers.MaxPooling2D((2, 2), strides=2),

    # Convolutional Layer 2
    layers.Conv2D(32, (3, 3), activation="relu", padding="same"),
    layers.MaxPooling2D((2, 2), strides=2),

    # Flatten Layer
    layers.Flatten(),

    # Fully Connected Network
    layers.Dense(64, activation="relu"),
    layers.Dense(128, activation="relu"),

    # Output Layer
    layers.Dense(num_classes, activation="softmax")
])

# %% [markdown]
# # Task 4: Compile the Model
# **Model Compilation**
#
# Choose an appropriate optimizer (e.g., Adam), loss function (e.g., sparse categorical crossentropy), and evaluation metric (e.g., accuracy).

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Print the model summary
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 64, 64, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 64)                  │       2,097,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Train the Model
# **Model Training**
#
# Use the model.fit() function to train the model. Set the batch size to 16 and the number of epochs to 250.
#
# Use val ds for validation.
#
# Use callbacks such as ModelCheckpoint and EarlyStopping for saving the best model and avoid- ing overfitting.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True, mode='min', verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True, verbose=1)
# Train the model
history = model.fit(train_ds,
    validation_data=val_ds, epochs=200, batch_size=32, callbacks=[checkpoint, early_stopping] )
# Out:
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.1256 - loss: 2.1327
# Epoch 1: val_loss improved from inf to 2.86822, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 849ms/step - accuracy: 0.1220 - loss: 2.1780 - val_accuracy: 0.0000e+00 - val_loss: 2.8682
# Epoch 2/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3125 - loss: 1.9471
# Epoch 2: val_loss improved from 2.86822 to 2.07592, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.3485 - loss: 1.8641 - val_accuracy: 0.0000e+00 - val_loss: 2.0759
# Epoch 3/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.1562 - loss: 1.7021
# Epoch 3: val_loss improved from 2.07592 to 1.92639, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.1645 - loss: 1.7031 - val_accuracy: 0.0000e+00 - val_loss: 1.9264
# Epoch 4/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3125 - loss: 1.6590
# Epoch 4: val_loss did not improve from 1.92639
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.3082 - loss: 1.6226 - val_accuracy: 0.0000e+00 - val_loss: 2.0762
# Epoch 5/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.2812 - loss: 1.4825
# Epoch 5: val_loss improved from 1.92639 to 1.89950, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3190 - loss: 1.4516 - val_accuracy: 0.0000e+00 - val_loss: 1.8995
# Epoch 6/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5000 - loss: 1.2976
# Epoch 6: val_loss improved from 1.89950 to 1.55476, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5464 - loss: 1.2401 - val_accuracy: 0.2222 - val_loss: 1.5548
# Epoch 7/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5938 - loss: 0.9937
# Epoch 7: val_loss improved from 1.55476 to 1.42292, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.6319 - loss: 0.9865 - val_accuracy: 0.3333 - val_loss: 1.4229
# Epoch 8/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6250 - loss: 0.8750
# Epoch 8: val_loss improved from 1.42292 to 0.61659, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7079 - loss: 0.7834 - val_accuracy: 0.8889 - val_loss: 0.6166
# Epoch 9/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7500 - loss: 0.7287
# Epoch 9: val_loss did not improve from 0.61659
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7648 - loss: 0.7086 - val_accuracy: 0.6667 - val_loss: 0.8448
# Epoch 10/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9688 - loss: 0.3329
# Epoch 10: val_loss did not improve from 0.61659
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8984 - loss: 0.4249 - val_accuracy: 0.3889 - val_loss: 1.5811
# Epoch 11/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8750 - loss: 0.3528
# Epoch 11: val_loss improved from 0.61659 to 0.52654, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8533 - loss: 0.4020 - val_accuracy: 0.8333 - val_loss: 0.5265
# Epoch 12/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.1547
# Epoch 12: val_loss improved from 0.52654 to 0.37936, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.9605 - loss: 0.2250 - val_accuracy: 0.8333 - val_loss: 0.3794
# Epoch 13/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9062 - loss: 0.2015
# Epoch 13: val_loss improved from 0.37936 to 0.32140, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8789 - loss: 0.2939 - val_accuracy: 0.8333 - val_loss: 0.3214
# Epoch 14/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9688 - loss: 0.1686
# Epoch 14: val_loss did not improve from 0.32140
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9674 - loss: 0.1608 - val_accuracy: 0.7222 - val_loss: 0.7243
# Epoch 15/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9688 - loss: 0.1300
# Epoch 15: val_loss did not improve from 0.32140
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9813 - loss: 0.1325 - val_accuracy: 0.7222 - val_loss: 0.6955
# Epoch 16/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9375 - loss: 0.1180
# Epoch 16: val_loss did not improve from 0.32140
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9627 - loss: 0.1037 - val_accuracy: 0.8889 - val_loss: 0.3516
# Epoch 17/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9688 - loss: 0.0566
# Epoch 17: val_loss improved from 0.32140 to 0.26545, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.9813 - loss: 0.0491 - val_accuracy: 0.8889 - val_loss: 0.2655
# Epoch 18/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0441
# Epoch 18: val_loss improved from 0.26545 to 0.25067, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 1.0000 - loss: 0.0408 - val_accuracy: 0.8889 - val_loss: 0.2507
# Epoch 19/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0260
# Epoch 19: val_loss improved from 0.25067 to 0.20926, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0213 - val_accuracy: 0.8889 - val_loss: 0.2093
# Epoch 20/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 1.0000 - loss: 0.0091
# Epoch 20: val_loss improved from 0.20926 to 0.20373, saving model to best_model.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.8889 - val_loss: 0.2037
# Epoch 21/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 21: val_loss did not improve from 0.20373
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.8889 - val_loss: 0.2236
# Epoch 22/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 22: val_loss did not improve from 0.20373
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8889 - val_loss: 0.2838
# Epoch 23/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 23: val_loss did not improve from 0.20373
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8889 - val_loss: 0.3086
# Epoch 24/200
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 24: val_loss did not improve from 0.20373
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8889 - val_loss: 0.3069
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 20.

# %%
val_loss, val_acc = model.evaluate(val_ds)
print(f'Validation Accuracy: {val_acc:.4f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8889 - loss: 0.2037
# Validation Accuracy: 0.8889

# %%
# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(test_ds)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step - accuracy: 0.7333 - loss: 0.7251
# Test Loss: 0.7250695824623108
# Test Accuracy: 0.7333333492279053

# %%
# Plot training and validation accuracy
plt.figure(figsize=(7, 7))
# Accuracy plot

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Loss plot
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Task 6: Save and Load the Model
# Model Saving and Loading
#
# Save the trained model to an .h5 file using model.save().
# Load the saved model and re-evaluate its performance on the test set.

# %% [markdown]
# Saving Model

# %%
# Save the trained model to an .h5 file
model.save('fruit_model.h5')

# %%
# Load the saved model
loaded_model = tf.keras.models.load_model('fruit_model.h5')

# Re-evaluate the model on the test dataset
loss, accuracy = loaded_model.evaluate(test_ds)

print('Test Loss (Loaded Model):', loss)
print('Test Accuracy (Loaded Model):', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.7333 - loss: 0.7251
# Test Loss (Loaded Model): 0.7250695824623108
# Test Accuracy (Loaded Model): 0.7333333492279053

# %% [markdown]
# # Task 7: Predictions and Classification Report
# Making Predictions
#
# Use model.predict() to make predictions on test images.
# Convert the model’s predicted probabilities to digit labels using np.argmax().
# Also use from sklearn.metrics import classification report to report the Classification Report of your Model Performance.

# %%
# Make predictions
predictions = model.predict(test_ds)

# Convert probabilities to digit labels
predicted_labels = np.argmax(predictions, axis=1)

# Get true labels from the test dataset
true_labels = []
for images, labels in test_ds.unbatch():  # Unbatch the dataset to get individual labels
    true_labels.append(labels.numpy())  # Use append instead of extend

# Generate classification report
report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#               precision    recall  f1-score   support
#
#            0       0.57      0.80      0.67         5
#            1       0.62      1.00      0.77         5
#            2       1.00      0.80      0.89         5
#            3       1.00      0.40      0.57         5
#            4       0.83      1.00      0.91         5
#            5       0.67      0.40      0.50         5
#
#     accuracy                           0.73        30
#    macro avg       0.78      0.73      0.72        30
# weighted avg       0.78      0.73      0.72        30
